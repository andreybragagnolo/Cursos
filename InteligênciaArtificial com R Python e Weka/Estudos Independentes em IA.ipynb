# %%
import pandas as pd
diabetes = pd.read_csv('pima-indians-diabetes.csv')
diabetes.head()
# Out:
#    # 1. Number of times pregnant  \
# 0                              6
# 1                              1
# 2                              8
# 3                              1
# 4                              0
#
#    # 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    # 3. Diastolic blood pressure (mm Hg)  \
# 0                                     72
# 1                                     66
# 2                                     64
# 3                                     66
# 4                                     40
#
#    # 4. Triceps skin fold thickness (mm)  # 5. 2-Hour serum insulin (mu U/ml)  \
# 0                                     35                                    0
# 1                                     29                                    0
# 2                                      0                                    0
# 3                                     23                                   94
# 4                                     35                                  168
#
#    # 6. Body mass index (weight in kg/(height in m)^2)  \
# 0                                               33.6
# 1                                               26.6
# 2                                               23.3
# 3                                               28.1
# 4                                               43.1
#
#    # 7. Diabetes pedigree function  # 8. Age (years)  \
# 0                            0.627                50
# 1                            0.351                31
# 2                            0.672                32
# 3                            0.167                21
# 4                            2.288                33
#
#    # 9. Class variable (0 or 1)
# 0                             1
# 1                             0
# 2                             1
# 3                             0
# 4                             1

# %%
#limpando os dados
cols_to_norm = ['Number_pregnant','glucose_concentration',
                'Blood_pressure', 'triceps', 'insulin', 'BMI','Pedigree']
diabetes[cols_to_norm]=diabetes[cols_to_norm].apply(lambda x: (x-x.min())/(x.max()-x.min()))
diabetes.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-5992f1c2962b> in <module>
#       2 cols_to_norm = ['Number_pregnant','glucose_concentration',
#       3                 'Blood_pressure', 'triceps', 'insulin', 'BMI','Pedigree']
# ----> 4 diabetes[cols_to_norm]=diabetes[cols_to_norm].apply(lambda x: (x-x.min())/(x.max()-x.min()))
#       5 diabetes.head()
#       6
#
# ~\Anaconda3\envs\rstudio\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\envs\rstudio\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~\Anaconda3\envs\rstudio\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\envs\rstudio\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['Number_pregnant', 'glucose_concentration', 'Blood_pressure', 'triceps',\n       'insulin', 'BMI', 'Pedigree'],\n      dtype='object')] are in the [columns]"
