# %%
#Redes Neurais Artificiais -> Entradas (atributos) para uma previsão. Estruturação em K camadas
#Todos os neurônios são ligados à neurônios de outras camadas -> Camada densa. 
#Relacionadas operações com matrizes e cálculos aplicados
#Uma rede Neural traz o melhor conjunto de neurônios através da comunicação entre as camadas (w-> Pesos) utilizada função somatória dos pesos com saída X em conjunto com 
#Função Sigmoide.

# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualização de dados
import matplotlib.pyplot as plt #visualização de dados

# %%
empregado_df = pd.read_csv('C:/Users/andy_/Documents/CursosUdemy - Arquivos/Ciência de Dados para Empresas e Finanças/Recursos Humanos/Bases de dados/Human_Resources.csv')

# %%
saidas_df = empregado_df[empregado_df['Attrition']==1]
continuidade_df = empregado_df[empregado_df['Attrition']==0]
temporario_cat = empregado_df[['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus']]
temporario_cat
temporario_cat = pd.DataFrame(temporario_cat)
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder()
temporario_cat = onehotencoder.fit_transform(temporario_cat).toarray()
temporario_cat.shape
type(temporario_cat)
temporario_cat = pd.DataFrame(temporario_cat)
temporario_num = empregado_df[['Age','DailyRate','DistanceFromHome','Education','EnvironmentSatisfaction','HourlyRate','JobInvolvement','JobLevel','JobSatisfaction','PerformanceRating','RelationshipSatisfaction','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
temporario_num = pd.DataFrame(temporario_num)
temp_geral = pd.concat([temporario_cat,temporario_num], axis =1)
temp_geral
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(temp_geral)
y = empregado_df['Attrition'].apply(lambda x: 1 if x=='Yes' else 0)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.25)
X_train.shape, Y_train
# Out:
# ((1102, 45),
#  1298    1
#  1070    0
#  302     0
#  283     0
#  482     1
#         ..
#  602     0
#  1451    0
#  1435    0
#  1157    0
#  131     0
#  Name: Attrition, Length: 1102, dtype: int64)

# %%
import tensorflow as tf

# %%
rede_neural = tf.keras.models.Sequential()
rede_neural.add(tf.keras.layers.Dense(units = 23, activation = 'relu', input_shape = (45,)))
rede_neural.add(tf.keras.layers.Dense(units = 23, activation = 'relu'))
rede_neural.add(tf.keras.layers.Dense(units = 23, activation = 'relu'))
rede_neural.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

#ativação = relu, sigmoid, etc...
#formula para definir -> por exemplo, 45 atributos, resultado da classificação (45+1)/2 = 23 ~> numero de neurônios

# %%
rede_neural.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 23)                1058
# _________________________________________________________________
# dense_12 (Dense)             (None, 23)                552
# _________________________________________________________________
# dense_13 (Dense)             (None, 23)                552
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 24
# ...
# Total params: 2,186
# Trainable params: 2,186
# Non-trainable params: 0
# _________________________________________________________________

# %%
rede_neural.compile(optimizer ='Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
rede_neural.fit(X_train, Y_train, epochs = 250)
# Out:
# Epoch 1/250
# 35/35 [==============================] - 1s 1ms/step - loss: 0.7560 - accuracy: 0.3628
# Epoch 2/250
# 35/35 [==============================] - 0s 784us/step - loss: 0.4569 - accuracy: 0.8377
# Epoch 3/250
# 35/35 [==============================] - 0s 858us/step - loss: 0.3937 - accuracy: 0.8505
# Epoch 4/250
# 35/35 [==============================] - 0s 890us/step - loss: 0.3919 - accuracy: 0.8464
# Epoch 5/250
# 35/35 [==============================] - 0s 908us/step - loss: 0.3888 - accuracy: 0.8457
# Epoch 6/250
# 35/35 [==============================] - 0s 896us/step - loss: 0.3664 - accuracy: 0.8502
# Epoch 7/250
# 35/35 [==============================] - 0s 982us/step - loss: 0.3903 - accuracy: 0.8497
# Epoch 8/250
# 35/35 [==============================] - 0s 905us/step - loss: 0.3682 - accuracy: 0.8517
# Epoch 9/250
# 35/35 [==============================] - 0s 871us/step - loss: 0.3640 - accuracy: 0.8599
# Epoch 10/250
# ...

# %%
ypred = rede_neural.predict (X_test)

# %%
ypred
# Out:
# array([[5.10890459e-08],
#        [2.76542857e-17],
#        [1.60954172e-09],
#        [4.88460888e-13],
#        [6.95600244e-09],
#        [3.77222663e-11],
#        [4.28324511e-17],
#        [3.94726098e-02],
#        [8.31311677e-14],
#        [2.88428032e-06],
#        [1.39871560e-07],
#        [7.03527689e-08],
#        [8.27343749e-12],
#        [1.82191400e-08],
#        [1.83381601e-16],
#        [4.37033009e-07],
#        [6.61437438e-09],
#        [7.62809934e-20],
#        [1.25894061e-07],
#        [2.30166559e-12],
#        [1.00000000e+00],
#        [7.29196868e-13],
#        [1.42963809e-16],
#        [8.88494900e-26],
#        [1.53014255e-07],
#        [5.94407192e-15],
#        [1.00000000e+00],
#        [6.25645993e-11],
#        [5.02914691e-06],
#        [2.74393369e-06],
#        [2.78552193e-07],
#        [6.27130774e-08],
#        [5.25787482e-06],
#        [2.77931008e-07],
#        [4.82425094e-03],
#        [5.43181591e-20],
#        [1.15224020e-12],
# ...

# %%
ypred = (ypred>=0.5)
ypred
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
cm = confusion_matrix
